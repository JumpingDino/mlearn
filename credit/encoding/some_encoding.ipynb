# %%
df
# Out:
#        Unnamed: 0      car_brand        car_model  car_price   car_city  \
# 0               0           Ford        Focus         550000  Astrakhan
# 1               1  Mercedes-Benz    GLA-Class        1820000  Astrakhan
# 2               2          Haval           F7        2600000  Astrakhan
# 3               3         Toyota        Camry        4200000  Astrakhan
# 4               4          OMODA           C5        2125000  Astrakhan
# ...           ...            ...              ...        ...        ...
# 42084       42084          Isuzu      Bighorn         450000    Yakutsk
# 42085       42085         Toyota  Corolla Axio        650000    Yakutsk
# 42086       42086       Daihatsu        Be-Go        1350000    Yakutsk
# 42087       42087          Mazda      Tribute         550000    Yakutsk
# 42088       42088          Lexus        GX460        4000000    Yakutsk
#
#        car_fuel car_transmission car_drive  car_mileage car_country  \
# 0      gasoline           manual       FWD       300000         USA
# 1      gasoline            robot       FWD        88000          DE
# 2      gasoline            robot       4WD        19000          CN
# 3      gasoline        automatic       FWD        30000          JP
# 4      gasoline              CVT       FWD        18824          CN
# ...         ...              ...       ...          ...         ...
# 42084    diesel        automatic       4WD       183212          JP
# 42085  gasoline              CVT       FWD       110000          JP
# 42086  gasoline        automatic       4WD       153000          JP
# 42087  gasoline        automatic       4WD       190000          JP
# 42088  gasoline        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 0                      1.8            125       14
# 1                      1.6            156       10
# 2                      1.5            150        2
# 3                      3.5            249        2
# 4                      1.5            147        2
# ...                    ...            ...      ...
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# 42086                  1.5            109       13
# 42087                  2.0            129       23
# 42088                  4.6            296       13
#
# [42089 rows x 13 columns]

# %%
import pandas as pd

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

# df = pd.read_excel('../../datasets/taiwan_default_payments.xls', header=1)
# df = df.rename(columns = {'default payment next month':'y'})

df = pd.read_csv('../../datasets/car_data.csv')
train, test = train_test_split(df, test_size=0.20)

X_train = train.drop(columns = ['y'])
y_train = train['y']
X_test = test.drop(columns = ['y'])
y_test = test['y']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 12
#       9 df = pd.read_csv('../../datasets/car_data.csv')
#      10 train, test = train_test_split(df, test_size=0.20)
# ---> 12 X_train = train.drop(columns = ['y'])
#      13 y_train = train['y']
#      14 X_test = test.drop(columns = ['y'])
#
# File ~/mlearn/venv/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/mlearn/venv/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/mlearn/venv/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/mlearn/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['y'] not found in axis"

# %%
X_train['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    11246
# 1     8476
# 3     3904
# 5      226
# 4       99
# 6       38
# 0       11
# Name: count, dtype: int64

# %%
train.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'y'],
#       dtype='object')

# %%
ohe = OneHotEncoder()
ohe.fit(train)

le = LabelEncoder()
le.fit()

# %%
train[['EDUCATION', 'y']]
# Out:
#        EDUCATION  y
# 22222          1  0
# 11659          3  0
# 27109          2  0
# 4887           2  0
# 5034           1  1
# ...          ... ..
# 25156          3  0
# 21056          1  1
# 15241          2  0
# 25737          2  0
# 15178          2  0
#
# [24000 rows x 2 columns]

# %%
df['EDUCATION']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 29995    3
# 29996    3
# 29997    2
# 29998    3
# 29999    2
# Name: EDUCATION, Length: 30000, dtype: int64
